# %% [markdown]
# # Kaggle Dogs Vs. Cats 데이터셋 준비하기

# %% [markdown]
# ## 다운로드하기

# %%
# !wget --no-check-certificate \
https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
-O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2022-08-29 05:48:34--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.199.128, 74.125.20.128, 108.177.98.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.199.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M   217MB/s    in 0.3s
#
# 2022-08-29 05:48:34 (217 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %% [markdown]
# ## 압축풀기

# %%
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'

zip_ref = zipfile.ZipFile(local_zip, 'r')

zip_ref.extractall('/tmp')
zip_ref.close()

# %% [markdown]
# ## 경로 지정하기

# %%
# 기본 경로
base_dir = '/tmp/cats_and_dogs_filtered'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# 훈련에 사용되는 고양이/개 이미지 경로
train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')
print(train_cats_dir)
print(train_dogs_dir)

# 테스트에 사용되는 고양이/개 이미지 경로
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')
print(validation_cats_dir)
print(validation_dogs_dir)
# Out:
# /tmp/cats_and_dogs_filtered/train/cats
# /tmp/cats_and_dogs_filtered/train/dogs
# /tmp/cats_and_dogs_filtered/validation/cats
# /tmp/cats_and_dogs_filtered/validation/dogs

# %% [markdown]
# # Kaggle Dogs Vs. Cats 데이터셋 살펴보기
# ## 파일 이름과 개수

# %%
train_cat_fnames = os.listdir( train_cats_dir )
train_dog_fnames = os.listdir( train_dogs_dir )

print(train_cat_fnames[:5])
print(train_dog_fnames[:5])
# Out:
# ['cat.930.jpg', 'cat.649.jpg', 'cat.458.jpg', 'cat.205.jpg', 'cat.78.jpg']
# ['dog.734.jpg', 'dog.74.jpg', 'dog.468.jpg', 'dog.464.jpg', 'dog.170.jpg']

# %% [markdown]
# os.listdir() 메서드는 경로 내에 있는 파일의 이름을 리스트의 형태로 반환합니다.
#
# 각각 다섯 개씩 출력했습니다.

# %%
print('Total training cat images :', len(os.listdir(train_cats_dir)))
print('Total training dog images :', len(os.listdir(train_dogs_dir)))

print('Total validation cat images :', len(os.listdir(validation_cats_dir)))
print('Total validation dog images :', len(os.listdir(validation_dogs_dir)))
# Out:
# Total training cat images : 1000
# Total training dog images : 1000
# Total validation cat images : 500
# Total validation dog images : 500

# %% [markdown]
# 각 경로에 있는 파일명 리스트의 길이를 통해 파일의 개수를 확인합니다.

# %% [markdown]
# ## 이미지 확인하기

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

nrows, ncols = 4, 4
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

pic_index+=8

next_cat_pix = [os.path.join(train_cats_dir, fname)
                for fname in train_cat_fnames[ pic_index-8:pic_index]]

next_dog_pix = [os.path.join(train_dogs_dir, fname)
                for fname in train_dog_fnames[ pic_index-8:pic_index]]

for i, img_path in enumerate(next_cat_pix+next_dog_pix):
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off')

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# Matplotlib 라이브러리를 이용해서 이미지를 출력해보면, 데이터셋에 아래와 같은 이미지들이 포함되어 있음을 알 수 있습니다.

# %% [markdown]
# # 모델 구성하기

# %%
import tensorflow as tf


model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 이제 TensorFlow를 이용해서 합성곱 신경망의 모델을 구성합니다.
#
# summary() 메서드를 이용해서 신경망의 구조를 확인할 수 있습니다.

# %% [markdown]
# # 모델 컴파일하기

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer=RMSprop(lr=0.001),
            loss='binary_crossentropy',
            metrics = ['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %% [markdown]
# 모델 컴파일 단계에서는 compile() 메서드를 이용해서 손실 함수 (loss function)와 옵티마이저 (optimizer)를 지정합니다.
#
# [말과 사람 이미지 분류하기 예제](https://codetorial.net/tensorflow/classifying_the_horse_and_human.html)에서와 같이 손실 함수로 ‘binary_crossentropy’를 사용했습니다.
#
# 출력층의 활성화함수로 ‘sigmoid’를 사용했고, 이는 0과 1 두 가지로 분류되는 ‘binary’ 분류 문제에 적합하기 때문입니다.
#
# 또한, 옵티마이저로는 [RMSprop](https://en.wikipedia.org/wiki/Stochastic_gradient_descent#RMSProp)을 사용했습니다.
#
# RMSprop (Root Mean Square Propagation) Algorithm은 훈련 과정 중에 학습률을 적절하게 변화시킵니다.

# %% [markdown]
# # 이미지 데이터 전처리하기

# %% [markdown]
# 훈련을 진행하기 전, tf.keras.preprocessing.image 모듈의 ImageDataGenerator 클래스를 이용해서 데이터 전처리를 진행합니다.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )

train_generator = train_datagen.flow_from_directory(train_dir,
                                                  batch_size=20,
                                                  class_mode='binary',
                                                  target_size=(150, 150))
validation_generator =  test_datagen.flow_from_directory(validation_dir,
                                                       batch_size=20,
                                                       class_mode  = 'binary',
                                                       target_size = (150, 150))
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# 우선 ImageDataGenerator 객체의 rescale 파라미터를 이용해서 모든 데이터를 255로 나누어준 다음,
#
# flow_from_directory() 메서드를 이용해서 훈련과 테스트에 사용될 이미지 데이터를 만듭니다.
#
# 첫번째 인자로 이미지들이 위치한 경로를 입력하고, batch_size, class_mode를 지정합니다.
#
# target_size에 맞춰서 이미지의 크기가 조절됩니다.

# %% [markdown]
# # 모델 훈련하기
#
# fit() 메서드는 앞에서 구성한 Neural Network 모델을 훈련합니다.

# %%
history = model.fit(train_generator,
                    validation_data=validation_generator,
                    steps_per_epoch=100,
                    epochs=100,
                    validation_steps=50,
                    verbose=2)
# Out:
# Epoch 1/100
# 100/100 - 22s - loss: 0.8166 - accuracy: 0.5635 - val_loss: 0.6692 - val_accuracy: 0.5450 - 22s/epoch - 221ms/step
# Epoch 2/100
# 100/100 - 10s - loss: 0.6384 - accuracy: 0.6465 - val_loss: 0.7015 - val_accuracy: 0.6340 - 10s/epoch - 101ms/step
# Epoch 3/100
# 100/100 - 12s - loss: 0.5456 - accuracy: 0.7215 - val_loss: 0.5774 - val_accuracy: 0.7100 - 12s/epoch - 119ms/step
# Epoch 4/100
# 100/100 - 8s - loss: 0.4854 - accuracy: 0.7620 - val_loss: 0.5630 - val_accuracy: 0.7020 - 8s/epoch - 81ms/step
# Epoch 5/100
# 100/100 - 8s - loss: 0.4352 - accuracy: 0.8055 - val_loss: 0.5606 - val_accuracy: 0.7300 - 8s/epoch - 82ms/step
# Epoch 6/100
# 100/100 - 9s - loss: 0.3307 - accuracy: 0.8455 - val_loss: 0.6232 - val_accuracy: 0.7370 - 9s/epoch - 92ms/step
# Epoch 7/100
# 100/100 - 9s - loss: 0.2604 - accuracy: 0.8885 - val_loss: 0.6887 - val_accuracy: 0.7310 - 9s/epoch - 94ms/step
# Epoch 8/100
# 100/100 - 9s - loss: 0.1784 - accuracy: 0.9245 - val_loss: 0.9161 - val_accuracy: 0.7100 - 9s/epoch - 91ms/step
# Epoch 9/100
# 100/100 - 8s - loss: 0.1396 - accuracy: 0.9455 - val_loss: 0.9231 - val_accuracy: 0.7200 - 8s/epoch - 81ms/step
# Epoch 10/100
# 100/100 - 10s - loss: 0.0822 - accuracy: 0.9680 - val_loss: 1.2443 - val_accuracy: 0.7250 - 10s/epoch - 104ms/step
# Epoch 11/100
# 100/100 - 9s - loss: 0.0829 - accuracy: 0.9725 - val_loss: 1.0520 - val_accuracy: 0.7380 - 9s/epoch - 93ms/step
# Epoch 12/100
# 100/100 - 8s - loss: 0.0346 - accuracy: 0.9885 - val_loss: 1.4080 - val_accuracy: 0.7270 - 8s/epoch - 81ms/step
# Epoch 13/100
# 100/100 - 8s - loss: 0.0459 - accuracy: 0.9905 - val_loss: 1.6153 - val_accuracy: 0.7280 - 8s/epoch - 81ms/step
# Epoch 14/100
# 100/100 - 9s - loss: 0.0790 - accuracy: 0.9865 - val_loss: 1.6968 - val_accuracy: 0.7300 - 9s/epoch - 86ms/step
# Epoch 15/100
# 100/100 - 8s - loss: 0.0364 - accuracy: 0.9895 - val_loss: 1.8566 - val_accuracy: 0.7350 - 8s/epoch - 82ms/step
# Epoch 16/100
# 100/100 - 8s - loss: 0.0737 - accuracy: 0.9865 - val_loss: 1.7067 - val_accuracy: 0.7400 - 8s/epoch - 81ms/step
# Epoch 17/100
# 100/100 - 8s - loss: 0.0380 - accuracy: 0.9900 - val_loss: 2.1564 - val_accuracy: 0.7290 - 8s/epoch - 82ms/step
# Epoch 18/100
# 100/100 - 8s - loss: 0.0202 - accuracy: 0.9920 - val_loss: 1.7954 - val_accuracy: 0.7330 - 8s/epoch - 82ms/step
# Epoch 19/100
# 100/100 - 8s - loss: 0.0153 - accuracy: 0.9950 - val_loss: 2.1535 - val_accuracy: 0.7310 - 8s/epoch - 81ms/step
# Epoch 20/100
# 100/100 - 8s - loss: 0.0097 - accuracy: 0.9965 - val_loss: 2.4922 - val_accuracy: 0.7300 - 8s/epoch - 81ms/step
# Epoch 21/100
# 100/100 - 8s - loss: 0.0419 - accuracy: 0.9920 - val_loss: 2.4342 - val_accuracy: 0.7280 - 8s/epoch - 81ms/step
# Epoch 22/100
# 100/100 - 8s - loss: 0.0313 - accuracy: 0.9930 - val_loss: 2.4281 - val_accuracy: 0.7270 - 8s/epoch - 82ms/step
# Epoch 23/100
# 100/100 - 9s - loss: 0.0568 - accuracy: 0.9895 - val_loss: 2.0536 - val_accuracy: 0.7390 - 9s/epoch - 87ms/step
# Epoch 24/100
# 100/100 - 8s - loss: 0.0658 - accuracy: 0.9865 - val_loss: 2.5758 - val_accuracy: 0.7180 - 8s/epoch - 81ms/step
# Epoch 25/100
# 100/100 - 9s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.8459 - val_accuracy: 0.7330 - 9s/epoch - 90ms/step
# Epoch 26/100
# 100/100 - 8s - loss: 0.1061 - accuracy: 0.9895 - val_loss: 2.8766 - val_accuracy: 0.7270 - 8s/epoch - 83ms/step
# Epoch 27/100
# 100/100 - 8s - loss: 1.8455e-04 - accuracy: 1.0000 - val_loss: 2.9826 - val_accuracy: 0.7180 - 8s/epoch - 83ms/step
# Epoch 28/100
# 100/100 - 8s - loss: 0.1010 - accuracy: 0.9895 - val_loss: 2.7884 - val_accuracy: 0.7260 - 8s/epoch - 81ms/step
# Epoch 29/100
# 100/100 - 8s - loss: 1.5214e-04 - accuracy: 1.0000 - val_loss: 3.3353 - val_accuracy: 0.7360 - 8s/epoch - 82ms/step
# Epoch 30/100
# 100/100 - 8s - loss: 0.0253 - accuracy: 0.9955 - val_loss: 3.0281 - val_accuracy: 0.7200 - 8s/epoch - 81ms/step
# Epoch 31/100
# 100/100 - 8s - loss: 0.0171 - accuracy: 0.9960 - val_loss: 2.6751 - val_accuracy: 0.7240 - 8s/epoch - 81ms/step
# Epoch 32/100
# 100/100 - 8s - loss: 0.0332 - accuracy: 0.9970 - val_loss: 3.7741 - val_accuracy: 0.7250 - 8s/epoch - 82ms/step
# Epoch 33/100
# 100/100 - 8s - loss: 0.0440 - accuracy: 0.9955 - val_loss: 3.2280 - val_accuracy: 0.7290 - 8s/epoch - 82ms/step
# Epoch 34/100
# 100/100 - 8s - loss: 0.0149 - accuracy: 0.9975 - val_loss: 2.9891 - val_accuracy: 0.7410 - 8s/epoch - 81ms/step
# Epoch 35/100
# 100/100 - 8s - loss: 0.0089 - accuracy: 0.9975 - val_loss: 3.3362 - val_accuracy: 0.7170 - 8s/epoch - 82ms/step
# Epoch 36/100
# 100/100 - 8s - loss: 2.9393e-06 - accuracy: 1.0000 - val_loss: 3.4947 - val_accuracy: 0.7290 - 8s/epoch - 82ms/step
# Epoch 37/100
# 100/100 - 8s - loss: 0.0669 - accuracy: 0.9940 - val_loss: 3.2114 - val_accuracy: 0.7290 - 8s/epoch - 82ms/step
# Epoch 38/100
# 100/100 - 8s - loss: 0.0079 - accuracy: 0.9975 - val_loss: 3.3155 - val_accuracy: 0.7150 - 8s/epoch - 81ms/step
# Epoch 39/100
# 100/100 - 11s - loss: 0.0188 - accuracy: 0.9970 - val_loss: 3.4081 - val_accuracy: 0.7330 - 11s/epoch - 106ms/step
# Epoch 40/100
# 100/100 - 8s - loss: 0.0168 - accuracy: 0.9980 - val_loss: 2.9524 - val_accuracy: 0.7200 - 8s/epoch - 81ms/step
# Epoch 41/100
# 100/100 - 8s - loss: 0.0192 - accuracy: 0.9950 - val_loss: 3.3857 - val_accuracy: 0.7110 - 8s/epoch - 81ms/step
# Epoch 42/100
# 100/100 - 8s - loss: 0.0098 - accuracy: 0.9965 - val_loss: 3.0602 - val_accuracy: 0.7210 - 8s/epoch - 82ms/step
# Epoch 43/100
# 100/100 - 8s - loss: 0.0142 - accuracy: 0.9955 - val_loss: 3.0860 - val_accuracy: 0.7090 - 8s/epoch - 82ms/step
# Epoch 44/100
# 100/100 - 8s - loss: 0.0053 - accuracy: 0.9980 - val_loss: 2.7850 - val_accuracy: 0.7270 - 8s/epoch - 83ms/step
# Epoch 45/100
# 100/100 - 8s - loss: 0.0012 - accuracy: 0.9995 - val_loss: 3.7799 - val_accuracy: 0.7270 - 8s/epoch - 82ms/step
# Epoch 46/100
# 100/100 - 8s - loss: 0.0226 - accuracy: 0.9975 - val_loss: 4.5206 - val_accuracy: 0.7180 - 8s/epoch - 82ms/step
# Epoch 47/100
# 100/100 - 8s - loss: 8.7158e-04 - accuracy: 0.9995 - val_loss: 5.9927 - val_accuracy: 0.6940 - 8s/epoch - 82ms/step
# Epoch 48/100
# 100/100 - 8s - loss: 0.0352 - accuracy: 0.9970 - val_loss: 4.0499 - val_accuracy: 0.7270 - 8s/epoch - 80ms/step
# Epoch 49/100
# 100/100 - 8s - loss: 3.9256e-07 - accuracy: 1.0000 - val_loss: 4.1575 - val_accuracy: 0.7330 - 8s/epoch - 80ms/step
# Epoch 50/100
# 100/100 - 8s - loss: 0.0315 - accuracy: 0.9955 - val_loss: 4.1155 - val_accuracy: 0.7270 - 8s/epoch - 81ms/step
# Epoch 51/100
# 100/100 - 8s - loss: 0.0025 - accuracy: 0.9990 - val_loss: 4.5216 - val_accuracy: 0.7170 - 8s/epoch - 81ms/step
# Epoch 52/100
# 100/100 - 8s - loss: 0.0168 - accuracy: 0.9965 - val_loss: 3.4988 - val_accuracy: 0.7190 - 8s/epoch - 80ms/step
# Epoch 53/100
# 100/100 - 8s - loss: 2.6548e-05 - accuracy: 1.0000 - val_loss: 4.2456 - val_accuracy: 0.7280 - 8s/epoch - 80ms/step
# Epoch 54/100
# 100/100 - 9s - loss: 0.0230 - accuracy: 0.9965 - val_loss: 4.5302 - val_accuracy: 0.7190 - 9s/epoch - 89ms/step
# Epoch 55/100
# 100/100 - 8s - loss: 2.2837e-06 - accuracy: 1.0000 - val_loss: 4.6829 - val_accuracy: 0.7190 - 8s/epoch - 81ms/step
# Epoch 56/100
# 100/100 - 8s - loss: 0.0233 - accuracy: 0.9980 - val_loss: 4.5481 - val_accuracy: 0.7190 - 8s/epoch - 81ms/step
# Epoch 57/100
# 100/100 - 8s - loss: 0.0064 - accuracy: 0.9990 - val_loss: 4.6180 - val_accuracy: 0.7230 - 8s/epoch - 80ms/step
# Epoch 58/100
# 100/100 - 8s - loss: 0.0122 - accuracy: 0.9985 - val_loss: 4.5388 - val_accuracy: 0.7220 - 8s/epoch - 80ms/step
# Epoch 59/100
# 100/100 - 8s - loss: 0.0120 - accuracy: 0.9975 - val_loss: 5.1642 - val_accuracy: 0.7210 - 8s/epoch - 80ms/step
# Epoch 60/100
# 100/100 - 8s - loss: 0.0078 - accuracy: 0.9990 - val_loss: 7.4319 - val_accuracy: 0.7160 - 8s/epoch - 80ms/step
# Epoch 61/100
# 100/100 - 8s - loss: 0.0090 - accuracy: 0.9965 - val_loss: 5.9348 - val_accuracy: 0.6960 - 8s/epoch - 81ms/step
# Epoch 62/100
# 100/100 - 8s - loss: 0.0055 - accuracy: 0.9990 - val_loss: 5.0040 - val_accuracy: 0.7140 - 8s/epoch - 81ms/step
# Epoch 63/100
# 100/100 - 8s - loss: 2.9619e-07 - accuracy: 1.0000 - val_loss: 5.5517 - val_accuracy: 0.7280 - 8s/epoch - 81ms/step
# Epoch 64/100
# 100/100 - 8s - loss: 3.4636e-09 - accuracy: 1.0000 - val_loss: 5.6046 - val_accuracy: 0.7250 - 8s/epoch - 80ms/step
# Epoch 65/100
# 100/100 - 8s - loss: 4.6084e-10 - accuracy: 1.0000 - val_loss: 5.8039 - val_accuracy: 0.7270 - 8s/epoch - 80ms/step
# Epoch 66/100
# 100/100 - 8s - loss: 1.0614e-09 - accuracy: 1.0000 - val_loss: 5.8750 - val_accuracy: 0.7180 - 8s/epoch - 82ms/step
# Epoch 67/100
# 100/100 - 8s - loss: 1.0643e-10 - accuracy: 1.0000 - val_loss: 5.8868 - val_accuracy: 0.7130 - 8s/epoch - 81ms/step
# Epoch 68/100
# 100/100 - 8s - loss: 5.5447e-11 - accuracy: 1.0000 - val_loss: 5.8973 - val_accuracy: 0.7140 - 8s/epoch - 80ms/step
# Epoch 69/100
# 100/100 - 9s - loss: 5.3402e-11 - accuracy: 1.0000 - val_loss: 5.9040 - val_accuracy: 0.7160 - 9s/epoch - 89ms/step
# Epoch 70/100
# 100/100 - 8s - loss: 5.2373e-11 - accuracy: 1.0000 - val_loss: 5.9097 - val_accuracy: 0.7170 - 8s/epoch - 80ms/step
# Epoch 71/100
# 100/100 - 8s - loss: 5.3074e-11 - accuracy: 1.0000 - val_loss: 5.9143 - val_accuracy: 0.7170 - 8s/epoch - 80ms/step
# Epoch 72/100
# 100/100 - 8s - loss: 5.2466e-11 - accuracy: 1.0000 - val_loss: 5.9184 - val_accuracy: 0.7180 - 8s/epoch - 80ms/step
# Epoch 73/100
# 100/100 - 8s - loss: 5.3273e-11 - accuracy: 1.0000 - val_loss: 5.9222 - val_accuracy: 0.7190 - 8s/epoch - 81ms/step
# Epoch 74/100
# 100/100 - 8s - loss: 5.3780e-11 - accuracy: 1.0000 - val_loss: 5.9254 - val_accuracy: 0.7200 - 8s/epoch - 82ms/step
# Epoch 75/100
# 100/100 - 8s - loss: 5.3713e-11 - accuracy: 1.0000 - val_loss: 5.9285 - val_accuracy: 0.7200 - 8s/epoch - 82ms/step
# Epoch 76/100
# 100/100 - 8s - loss: 5.3810e-11 - accuracy: 1.0000 - val_loss: 5.9314 - val_accuracy: 0.7200 - 8s/epoch - 82ms/step
# Epoch 77/100
# 100/100 - 8s - loss: 5.4069e-11 - accuracy: 1.0000 - val_loss: 5.9341 - val_accuracy: 0.7210 - 8s/epoch - 81ms/step
# Epoch 78/100
# 100/100 - 8s - loss: 5.4684e-11 - accuracy: 1.0000 - val_loss: 5.9367 - val_accuracy: 0.7210 - 8s/epoch - 80ms/step
# Epoch 79/100
# 100/100 - 8s - loss: 5.4677e-11 - accuracy: 1.0000 - val_loss: 5.9392 - val_accuracy: 0.7230 - 8s/epoch - 80ms/step
# Epoch 80/100
# 100/100 - 8s - loss: 5.4973e-11 - accuracy: 1.0000 - val_loss: 5.9416 - val_accuracy: 0.7230 - 8s/epoch - 81ms/step
# Epoch 81/100
# 100/100 - 8s - loss: 5.5550e-11 - accuracy: 1.0000 - val_loss: 5.9438 - val_accuracy: 0.7230 - 8s/epoch - 81ms/step
# Epoch 82/100
# 100/100 - 8s - loss: 5.5607e-11 - accuracy: 1.0000 - val_loss: 5.9639 - val_accuracy: 0.7220 - 8s/epoch - 80ms/step
# Epoch 83/100
# 100/100 - 8s - loss: 3.3041e-11 - accuracy: 1.0000 - val_loss: 5.9652 - val_accuracy: 0.7220 - 8s/epoch - 80ms/step
# Epoch 84/100
# 100/100 - 9s - loss: 3.2727e-11 - accuracy: 1.0000 - val_loss: 5.9667 - val_accuracy: 0.7230 - 9s/epoch - 89ms/step
# Epoch 85/100
# 100/100 - 8s - loss: 3.2764e-11 - accuracy: 1.0000 - val_loss: 5.9681 - val_accuracy: 0.7230 - 8s/epoch - 81ms/step
# Epoch 86/100
# 100/100 - 8s - loss: 3.2788e-11 - accuracy: 1.0000 - val_loss: 5.9697 - val_accuracy: 0.7230 - 8s/epoch - 81ms/step
# Epoch 87/100
# 100/100 - 8s - loss: 3.2990e-11 - accuracy: 1.0000 - val_loss: 5.9712 - val_accuracy: 0.7240 - 8s/epoch - 81ms/step
# Epoch 88/100
# 100/100 - 8s - loss: 3.2853e-11 - accuracy: 1.0000 - val_loss: 5.9727 - val_accuracy: 0.7240 - 8s/epoch - 81ms/step
# Epoch 89/100
# 100/100 - 8s - loss: 3.3045e-11 - accuracy: 1.0000 - val_loss: 5.9743 - val_accuracy: 0.7240 - 8s/epoch - 80ms/step
# Epoch 90/100
# 100/100 - 8s - loss: 3.3149e-11 - accuracy: 1.0000 - val_loss: 5.9758 - val_accuracy: 0.7240 - 8s/epoch - 80ms/step
# Epoch 91/100
# 100/100 - 8s - loss: 3.3417e-11 - accuracy: 1.0000 - val_loss: 5.9773 - val_accuracy: 0.7250 - 8s/epoch - 81ms/step
# Epoch 92/100
# 100/100 - 8s - loss: 3.3459e-11 - accuracy: 1.0000 - val_loss: 5.9788 - val_accuracy: 0.7250 - 8s/epoch - 81ms/step
# Epoch 93/100
# 100/100 - 8s - loss: 3.3517e-11 - accuracy: 1.0000 - val_loss: 5.9803 - val_accuracy: 0.7240 - 8s/epoch - 81ms/step
# Epoch 94/100
# 100/100 - 8s - loss: 3.3657e-11 - accuracy: 1.0000 - val_loss: 5.9818 - val_accuracy: 0.7240 - 8s/epoch - 82ms/step
# Epoch 95/100
# 100/100 - 8s - loss: 3.3866e-11 - accuracy: 1.0000 - val_loss: 5.9832 - val_accuracy: 0.7240 - 8s/epoch - 82ms/step
# Epoch 96/100
# 100/100 - 8s - loss: 3.4298e-11 - accuracy: 1.0000 - val_loss: 5.9847 - val_accuracy: 0.7240 - 8s/epoch - 82ms/step
# Epoch 97/100
# 100/100 - 8s - loss: 3.4448e-11 - accuracy: 1.0000 - val_loss: 5.9861 - val_accuracy: 0.7240 - 8s/epoch - 81ms/step
# Epoch 98/100
# 100/100 - 9s - loss: 3.4329e-11 - accuracy: 1.0000 - val_loss: 5.9874 - val_accuracy: 0.7240 - 9s/epoch - 88ms/step
# Epoch 99/100
# 100/100 - 8s - loss: 3.4679e-11 - accuracy: 1.0000 - val_loss: 5.9887 - val_accuracy: 0.7240 - 8s/epoch - 80ms/step
# Epoch 100/100
# 100/100 - 8s - loss: 3.4896e-11 - accuracy: 1.0000 - val_loss: 5.9900 - val_accuracy: 0.7240 - 8s/epoch - 81ms/step

# %% [markdown]
# 훈련과 테스트를 위한 데이터셋인 train_generator, validation_generator를 입력합니다.
#
# epochs는 데이터셋을 한 번 훈련하는 과정을 의미합니다.
#
# steps_per_epoch는 한 번의 에포크 (epoch)에서 훈련에 사용할 배치 (batch)의 개수를 지정합니다.
#
# validation_steps는 한 번의 에포크가 끝날 때, 테스트에 사용되는 배치 (batch)의 개수를 지정합니다.
#
# 아래와 같은 훈련 과정을 확인할 수 있습니다.

# %% [markdown]
# # 정확도와 손실 확인하기

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# [Matplotlib 라이브러리](https://codetorial.net/matplotlib/index.html)를 이용해서 훈련 과정에서 에포크에 따른 정확도와 손실을 출력합니다.
#
# 아래와 같은 이미지가 출력됩니다.
#
# 20회 에포크에서 훈련 정확도는 1.0에 근접한 반면, 테스트의 정확도는 100회 훈련이 끝나도 0.7 수준에 머물고 있습니다.
#
# 이러한 현상을 과적합 (Overfitting)이라고 합니다.

# %% [markdown]
# # 테스트 이미지 분류하기

# %% [markdown]
# 아래의 테스트 이미지를 사용해서 훈련된 모델이 개와 고양이 이미지를 분류할 수 있는지 확인해 보겠습니다.

# %% [markdown]
# ![test_image.png](data:image/png;base64,...)
#
# test_image.png

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded=files.upload()

for fn in uploaded.keys():

  path='/content/' + fn
  img=image.load_img(path, target_size=(150, 150))

  x=image.img_to_array(img)
  x=np.expand_dims(x, axis=0)
  images = np.vstack([x])

  classes = model.predict(images, batch_size=10)

  print(classes[0])

  if classes[0]>0:
    print(fn + " is a dog")
  else:
    print(fn + " is a cat")
# Out:
# Saving test_image.png to test_image.png
# [1.]
# test_image.png is a dog

# %% [markdown]
# 이 코드는 하나 이상의 이미지를 업로드하고, 훈련된 모델을 사용해서 개/고양이 분류 결과를 출력합니다.
