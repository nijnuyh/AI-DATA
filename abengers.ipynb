# %% [markdown]
# <a href="https://colab.research.google.com/github/nijnuyh/nijnuyh/blob/main/abengers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mission 2. Abengers, Assemble!**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
stats_df = pd.read_csv("./charcters_stats.csv")

# %%
stats_df.dtypes
# Out:
# Name            object
# Alignment       object
# Intelligence     int64
# Strength         int64
# Speed            int64
# Durability       int64
# Power            int64
# Combat           int64
# Total            int64
# dtype: object

# %%
stats_df.describe()
# Out:
#        Intelligence    Strength       Speed  Durability       Power  \
# count    611.000000  611.000000  611.000000  611.000000  611.000000
# mean      44.502455   29.083470   27.306056   41.839607   40.312602
# std       32.924722   32.610939   25.760173   36.543849   34.539910
# min        1.000000    1.000000    1.000000    1.000000    0.000000
# 25%        1.000000    1.000000    1.000000    1.000000    0.000000
# 50%       50.000000   10.000000   23.000000   32.000000   37.000000
# 75%       75.000000   53.000000   42.000000   80.000000   67.000000
# max      113.000000  100.000000  100.000000  120.000000  100.000000
#
#            Combat       Total
# count  611.000000  611.000000
# mean    43.206219  226.250409
# std     33.270329  167.324034
# min      1.000000    5.000000
# 25%      1.000000    5.000000
# 50%     50.000000  255.000000
# 75%     70.000000  351.500000
# max    101.000000  581.000000

# %% [markdown]
# ## **Core Mission**

# %% [markdown]
# ### **능력치 총합 정렬**

# %%
stats_df[['Name','Total']].sort_values(by='Total', ascending=False)
# Out:
#                   Name  Total
# 361  Martian Manhunter    581
# 242        General Zod    579
# 535     Superboy-Prime    579
# 537           Superman    579
# 16               Amazo    575
# ..                 ...    ...
# 462       Renata Soliz      5
# 137   Captain Mar-vell      5
# 136       Captain Epic      5
# 466            Ripcord      5
# 335   Lady Deathstrike      5
#
# [611 rows x 2 columns]

# %% [markdown]
# 수치의 합이 가장 큰 캐릭터는 'Martian Manhunter' 이다.

# %% [markdown]
# ### **영웅과 악당의 능력 분포**

# %%
stats_df[stats_df.Alignment == 'good']['Total'].mean()
# Out:
# 214.99074074074073

# %%
stats_df[stats_df.Alignment == 'bad']['Total'].mean()
# Out:
# 247.21212121212122

# %%
fig, ax = plt.subplots(1,1, figsize=(10,5))
sns.kdeplot(stats_df[stats_df['Alignment']== 'good']['Total'], ax=ax)
sns.kdeplot(stats_df[stats_df['Alignment']== 'bad']['Total'], ax=ax)

plt.legend(['good', 'bad'])
plt.show()

# %% [markdown]
# ## **Extra Mission**

# %%
info_df = pd.read_csv("./marvel_characters_info.csv")

# %%
# 코믹스 회사 알아보기

marvel_company = info_df['Publisher'].unique()
marvel_company
# Out:
# array(['Marvel Comics', 'Dark Horse Comics', 'DC Comics', 'NBC - Heroes',
#        'Wildstorm', 'Image Comics', nan, 'Icon Comics', 'SyFy',
#        'Hanna-Barbera', 'George Lucas', 'Team Epic TV', 'South Park',
#        'HarperCollins', 'ABC Studios', 'Universal Studios', 'Star Trek',
#        'IDW Publishing', 'Shueisha', 'Sony Pictures', 'J. K. Rowling',
#        'Titan Books', 'Rebellion', 'Microsoft', 'J. R. R. Tolkien'],
#       dtype=object)

# %%
# marvel의 회사 값이 있는 df와 캐릭터 능력치가 있는 df 합치기

avengers = pd.merge(stats_df,info_df,on = "Name", how = 'outer')
avengers
# Out:
#              Name Alignment_x  Intelligence  Strength  Speed  Durability  \
# 0         3-D Man        good          50.0      31.0   43.0        32.0
# 1          A-Bomb        good          38.0     100.0   17.0        80.0
# 2      Abe Sapien        good          88.0      14.0   35.0        42.0
# 3        Abin Sur        good          50.0      90.0   53.0        64.0
# 4     Abomination         bad          63.0      80.0   53.0        90.0
# ..            ...         ...           ...       ...    ...         ...
# 760          Vibe         NaN           NaN       NaN    NaN         NaN
# 761   Violet Parr         NaN           NaN       NaN    NaN         NaN
# 762         Vixen         NaN           NaN       NaN    NaN         NaN
# 763  White Canary         NaN           NaN       NaN    NaN         NaN
# 764          Yoda         NaN           NaN       NaN    NaN         NaN
#
#      Power  Combat  Total     ID Alignment_y  Gender EyeColor  \
# ...

# %%
# totla 능력치가 NaN인 행 제거

avengers = avengers.dropna(axis=0)
avengers
# Out:
#                 Name Alignment_x  Intelligence  Strength  Speed  Durability  \
# 1             A-Bomb        good          38.0     100.0   17.0        80.0
# 2         Abe Sapien        good          88.0      14.0   35.0        42.0
# 3           Abin Sur        good          50.0      90.0   53.0        64.0
# 4        Abomination         bad          63.0      80.0   53.0        90.0
# 5            Abraxas         bad          88.0     100.0   83.0        99.0
# ..               ...         ...           ...       ...    ...         ...
# 624     Yellowjacket        good          88.0      10.0   12.0        28.0
# 625  Yellowjacket II        good          50.0      10.0   35.0        28.0
# 626             Ymir        good          50.0     100.0   27.0       100.0
# 627          Zatanna        good          75.0      10.0   23.0        28.0
# 628             Zoom         bad          50.0      10.0  100.0        28.0
#
# ...

# %%
# marvel과 dc인 캐릭터만 가져오기

marvel_df = avengers[avengers.Publisher == 'Marvel Comics']
marvel_df.head()
# Out:
#            Name Alignment_x  Intelligence  Strength  Speed  Durability  Power  \
# 1        A-Bomb        good          38.0     100.0   17.0        80.0   17.0
# 4   Abomination         bad          63.0      80.0   53.0        90.0   55.0
# 5       Abraxas         bad          88.0     100.0   83.0        99.0  100.0
# 9     Agent Bob        good          10.0       8.0   13.0         5.0    5.0
# 10   Agent Zero        good          75.0      28.0   38.0        80.0   72.0
#
#     Combat  Total    ID Alignment_y Gender EyeColor               Race  \
# 1     64.0  316.0   0.0        good   Male   yellow              Human
# 4     95.0  436.0   3.0         bad   Male    green  Human / Radiation
# 5     56.0  526.0   4.0         bad   Male     blue      Cosmic Entity
# 9     20.0   61.0   9.0        good   Male    brown              Human
# 10    95.0  388.0  10.0        good   Male        -                  -
#
#    HairColor      Publisher SkinColor  Height  Weight
# ...

# %%
dc_df =avengers[avengers.Publisher == 'DC Comics']
dc_df.head()
# Out:
#                  Name Alignment_x  Intelligence  Strength  Speed  Durability  \
# 3            Abin Sur        good          50.0      90.0   53.0        64.0
# 7        Adam Strange        good           1.0       1.0    1.0         1.0
# 12         Alan Scott        good          63.0      80.0   23.0        90.0
# 14  Alfred Pennyworth        good          63.0      10.0   17.0        10.0
# 16              Amazo         bad          75.0     100.0  100.0       100.0
#
#     Power  Combat  Total    ID Alignment_y Gender EyeColor     Race HairColor  \
# 3    84.0    65.0  406.0   2.0        good   Male     blue  Ungaran   No Hair
# 7     0.0     1.0    5.0   7.0        good   Male     blue    Human     Blond
# 12   98.0    32.0  386.0  13.0        good   Male     blue        -     Blond
# 14    7.0    55.0  162.0  16.0        good   Male     blue    Human     Black
# 16  100.0   100.0  575.0  19.0         bad   Male      red  Android         -
#
# ...

# %%
# 마블 캐릭터 능력치 평균

marvel_df['Total'].mean()
# Out:
# 243.35734870317003

# %%
# DC 능력치 평균

dc_df['Total'].mean()
# Out:
# 254.88888888888889

# %%
list1 = []

# 전체 회사 캐릭터 구하기

for i in marvel_company:
  new_df = avengers[avengers.Publisher == i]
  mean = new_df['Total'].mean()
  list1.append([i,mean])
list1 = pd.DataFrame(list1)
list1 = list1.set_index(list1[0],drop=True) 

# 어떠한 회사의 캐릭터들이 능력치 합의 평균이 가장 큰지?

list1[list1[1] == list1[1].max()]
# Out:
#                  0      1
# 0
# Shueisha  Shueisha  481.5

# %%
# 해당 회사의 캐릭터 평균 능력치
list1
# Out:
#                                    0           1
# 0
# Marvel Comics          Marvel Comics  243.357349
# Dark Horse Comics  Dark Horse Comics  196.875000
# DC Comics                  DC Comics  254.888889
# NBC - Heroes            NBC - Heroes  140.526316
# Wildstorm                  Wildstorm    5.000000
# Image Comics            Image Comics   70.615385
# NaN                              NaN         NaN
# Icon Comics              Icon Comics  148.000000
# SyFy                            SyFy  188.800000
# Hanna-Barbera          Hanna-Barbera    5.000000
# George Lucas            George Lucas         NaN
# Team Epic TV            Team Epic TV    5.000000
# South Park                South Park         NaN
# HarperCollins          HarperCollins    5.000000
# ABC Studios              ABC Studios  166.000000
# Universal Studios  Universal Studios  237.000000
# Star Trek                  Star Trek         NaN
# IDW Publishing        IDW Publishing         NaN
# ...

# %%
# 좋은 캐릭터 Info

good_avengers = avengers[avengers.Alignment_x == 'good']
good_avengers.head()
# Out:
#            Name Alignment_x  Intelligence  Strength  Speed  Durability  Power  \
# 1        A-Bomb        good          38.0     100.0   17.0        80.0   17.0
# 2    Abe Sapien        good          88.0      14.0   35.0        42.0   35.0
# 3      Abin Sur        good          50.0      90.0   53.0        64.0   84.0
# 6   Adam Monroe        good          63.0      10.0   12.0       100.0   71.0
# 7  Adam Strange        good           1.0       1.0    1.0         1.0    0.0
#
#    Combat  Total   ID Alignment_y Gender EyeColor           Race HairColor  \
# 1    64.0  316.0  0.0        good   Male   yellow          Human   No Hair
# 2    85.0  299.0  1.0        good   Male     blue  Icthyo Sapien   No Hair
# 3    65.0  406.0  2.0        good   Male     blue        Ungaran   No Hair
# 6    64.0  320.0  6.0        good   Male     blue              -     Blond
# 7     1.0    5.0  7.0        good   Male     blue          Human     Blond
#
# ...

# %%
# 나쁜 캐릭터 Info

bad_avengers = avengers[avengers.Alignment_x == 'bad']
bad_avengers.head()
# Out:
#            Name Alignment_x  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination         bad          63.0      80.0   53.0        90.0   55.0
# 5       Abraxas         bad          88.0     100.0   83.0        99.0  100.0
# 11   Air-Walker         bad          50.0      85.0  100.0        85.0  100.0
# 16        Amazo         bad          75.0     100.0  100.0       100.0  100.0
# 17         Ammo         bad           1.0       1.0    1.0         1.0    0.0
#
#     Combat  Total    ID Alignment_y Gender EyeColor               Race  \
# 4     95.0  436.0   3.0         bad   Male    green  Human / Radiation
# 5     56.0  526.0   4.0         bad   Male     blue      Cosmic Entity
# 11    40.0  460.0  11.0         bad   Male     blue                  -
# 16   100.0  575.0  19.0         bad   Male      red            Android
# 17     1.0    5.0  20.0         bad   Male    brown              Human
#
#    HairColor      Publisher SkinColor  Height  Weight
# ...

# %%
neutral_avengers = avengers[avengers.Alignment_x == 'neutral']
neutral_avengers.head()
# Out:
#             Name Alignment_x  Intelligence  Strength  Speed  Durability  \
# 86       Bizarro     neutral          75.0      95.0  100.0       100.0
# 193     Deadpool     neutral          50.0      15.0   30.0       100.0
# 196  Deathstroke     neutral          75.0      30.0   35.0       100.0
# 246     Galactus     neutral         100.0     100.0   83.0       100.0
# 328   Juggernaut     neutral          44.0     100.0   42.0       100.0
#
#      Power  Combat  Total     ID Alignment_y Gender EyeColor           Race  \
# 86    95.0    85.0  550.0   92.0     neutral   Male    black        Bizarro
# 193  100.0   100.0  395.0  212.0     neutral   Male    brown         Mutant
# 196   36.0    90.0  366.0  215.0     neutral   Male     blue          Human
# 246  100.0    70.0  553.0  272.0     neutral   Male    black  Cosmic Entity
# 328   74.0    70.0  430.0  373.0     neutral   Male     blue          Human
#
#     HairColor      Publisher SkinColor  Height  Weight
# ...

# %%
good_avengers.Total.mean()
# Out:
# 222.58949880668257

# %%
bad_avengers.Total.mean()
# Out:
# 251.95625

# %%
neutral_avengers.Total.mean()
# Out:
# 355.3636363636364

# %% [markdown]
# 좋은 캐릭터의 평균 능력치가 나쁜 캐릭터의 평균 능력치보다 낮기 때문에
#
# 중립 캐릭터들이 좋은 캐릭터에 가담하여 좋은 팀이 승리한다.
